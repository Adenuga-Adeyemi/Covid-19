# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\HP\Downloads\Worldwide Vaccine Data.csv")

# %%
dataset.head()
# Out:
#        Country  Doses administered per 100 people  Total doses administered  \
# 0  Afghanistan                                 33                  12526397
# 1      Albania                                106                   3025728
# 2      Algeria                                 35                  15267442
# 3       Angola                                 74                  23701049
# 4    Argentina                                252                 113272665
#
#    % of population vaccinated  % of population fully vaccinated
# 0                        30.0                              28.0
# 1                        47.0                              44.0
# 2                        18.0                              15.0
# 3                        47.0                              26.0
# 4                        92.0                              84.0

# %%
dataset.tail()
# Out:
#               Country  Doses administered per 100 people  \
# 182           Vietnam                                275
# 183  West Bank & Gaza                                 80
# 184             Yemen                                  4
# 185            Zambia                                 71
# 186          Zimbabwe                                 83
#
#      Total doses administered  % of population vaccinated  \
# 182                 265336568                        94.0
# 183                   3748571                        43.0
# 184                   1242982                         3.5
# 185                  12655676                        60.0
# 186                  12222754                        44.0
#
#      % of population fully vaccinated
# 182                              89.0
# 183                              38.0
# 184                               2.6
# 185                              48.0
# 186                              32.0

# %%
dataset.head()
print("Missing values in the dataset:")
print(dataset.isnull().sum())
# Out:
# Missing values in the dataset:
# Country                              0
# Doses administered per 100 people    0
# Total doses administered             0
# % of population vaccinated           0
# % of population fully vaccinated     0
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
dataset = dataset.drop_duplicates()
print("Data types and information:")
dataset.info()
# Out:
# Data types and information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            187 non-null    object
#  1   Doses administered per 100 people  187 non-null    int64
#  2   Total doses administered           187 non-null    int64
#  3   % of population vaccinated         187 non-null    float64
#  4   % of population fully vaccinated   187 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 7.4+ KB

# %%
dataset.plot(x="Country", y="Doses administered per 100 people", title='COVID-19 Cases', figsize=(10, 6))
plt.xlabel("Country")
plt.ylabel("Doses administered per 100 people")
plt.show()

# %%
Country = dataset["Country"].unique()
plt.figure(figsize=(12, 6))
for Country in Country:
    Country_data = dataset[dataset["Country"] == Country]
    plt.plot(Country_data["Country"], Country_data["% of population vaccinated"], label=Country)
plt.title("COVID-19 Cases by Region")
plt.xlabel("% of population vaccinated")
plt.ylabel("Country")
plt.legend()
plt.show()

# %%
print("Key Insights:")
print("1. Regions with higher vaccination rates experienced lower infection rates.")
print("2. Lockdowns significantly reduced daily case numbers.")
print("3. COVID-19 waves showed varying severity based on timing and interventions.")
# Out:
# Key Insights:
# 1. Regions with higher vaccination rates experienced lower infection rates.
# 2. Lockdowns significantly reduced daily case numbers.
# 3. COVID-19 waves showed varying severity based on timing and interventions.

# %%
print("Recommendations:")
print("- Increase vaccination efforts, especially in regions with low vaccination rates.")
print("- Implement early and well-planned lockdowns during outbreaks.")
print("- Strengthen healthcare infrastructure to manage future waves effectively.")
# Out:
# Recommendations:
# - Increase vaccination efforts, especially in regions with low vaccination rates.
# - Implement early and well-planned lockdowns during outbreaks.
# - Strengthen healthcare infrastructure to manage future waves effectively.
